# %% [markdown]
# ## Education Dataset

# %%
import pandas as pd

education_df = pd.read_csv("../data/raw_data/Education2023.csv")

# Clean the column titles
education_df.columns = [
    col.strip()
    .lower()
    .replace(" ", "_")
    .replace(",", "")
    .replace('"', "")
    .replace("(", "")
    .replace(")", "")
    for col in education_df.columns
]

# Replace spaces with underscores and keep lowercase for 'area_name'
education_df["area_name"] = education_df["area_name"].str.replace(" ", "_")

for col in education_df.columns:
    if education_df[col].dtype == "object":
        education_df[col] = education_df[col].str.replace(",", "")

for col in education_df.columns:
    try:
        education_df[col] = pd.to_numeric(education_df[col], errors="ignore")
    except ValueError:
        continue  # This column contains non-numeric data, skip it


education_df.to_csv("../data/clean_data/education.csv", index=False)
education_df.head()
# Out:
# C:\Users\court\AppData\Local\Temp\ipykernel_45476\3480385410.py:26: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   education_df[col] = pd.to_numeric(education_df[col], errors="ignore")
#    fips_code state       area_name  2013_urban_influence_code  \
# 0          0    US   United_States                        NaN
# 1       1000    AL         Alabama                        NaN
# 2       1001    AL  Autauga_County                        2.0
# 3       1003    AL  Baldwin_County                        2.0
# 4       1005    AL  Barbour_County                        6.0
#
#    2024_urban_influence_code  2013_rural-urban_continuum_code  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        4.0                              2.0
# ...

# %% [markdown]
# ## Poverty Dataset

# %%
poverty_df = pd.read_csv("../data/raw_data/Poverty2023.csv")

poverty_df.columns = [
    col.strip()
    .lower()
    .replace(" ", "_")
    .replace(",", "")
    .replace('"', "")
    .replace("(", "")
    .replace(")", "")
    for col in poverty_df.columns
]


poverty_df["area_name"] = poverty_df["area_name"].str.replace(" ", "_")

for col in poverty_df.columns:
    if poverty_df[col].dtype == "object":
        poverty_df[col] = poverty_df[col].str.replace(",", "")

for col in poverty_df.columns:
    try:
        poverty_df[col] = pd.to_numeric(poverty_df[col], errors="ignore")
    except ValueError:
        continue


poverty_df.to_csv("../data/clean_data/poverty.csv", index=False)
poverty_df.head()
# Out:
# C:\Users\court\AppData\Local\Temp\ipykernel_45476\684472560.py:23: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   poverty_df[col] = pd.to_numeric(poverty_df[col], errors="ignore")
#    fips_code state       area_name  rural_urban_continuum_code_2013  \
# 0          0    US   United_States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga_County                              2.0
# 3       1003    AL  Baldwin_County                              3.0
# 4       1005    AL  Barbour_County                              6.0
#
#    urban_influence_code_2013  rural_urban_continuum_code_2023  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# ...

# %% [markdown]
# ## Unemployment Dataset

# %%
unemployment_df = pd.read_csv("../data/raw_data/Unemployment2023.csv")

unemployment_df.columns = [
    col.strip()
    .lower()
    .replace(" ", "_")
    .replace(",", "")
    .replace('"', "")
    .replace("(", "")
    .replace(")", "")
    for col in unemployment_df.columns
]

unemployment_df["area_name"] = unemployment_df["area_name"].str.replace(
    r",\s*[A-Z]{2}$", "", regex=True
)
unemployment_df["area_name"] = unemployment_df["area_name"].str.replace(" ", "_")

for col in unemployment_df.columns:
    if unemployment_df[col].dtype == "object":
        unemployment_df[col] = unemployment_df[col].str.replace(",", "")

for col in unemployment_df.columns:
    try:
        unemployment_df[col] = pd.to_numeric(unemployment_df[col], errors="ignore")
    except ValueError:
        continue


unemployment_df.to_csv("../data/clean_data/unemployment.csv", index=False)
unemployment_df.head()
# Out:
# C:\Users\court\AppData\Local\Temp\ipykernel_45476\190114105.py:25: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   unemployment_df[col] = pd.to_numeric(unemployment_df[col], errors="ignore")
#    fips_code state       area_name  rural_urban_continuum_code_2023  \
# 0          0    US   United_States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga_County                              2.0
# 3       1003    AL  Baldwin_County                              3.0
# 4       1005    AL  Barbour_County                              6.0
#
#    urban_influence_code_2013  metro_2023  civilian_labor_force_2000  \
# 0                        NaN         NaN                142601576.0
# 1                        NaN         NaN                  2147173.0
# ...

# %%
population_df = pd.read_csv("../data/raw_data/PopulationEstimates.csv")

population_df.columns = [
    col.strip()
    .lower()
    .replace(" ", "_")
    .replace(",", "")
    .replace('"', "")
    .replace("(", "")
    .replace(")", "")
    for col in population_df.columns
]

population_df["area_name"] = population_df["area_name"].str.replace(" ", "_")

for col in population_df.columns:
    if population_df[col].dtype == "object":
        population_df[col] = population_df[col].str.replace(",", "")

for col in population_df.columns:
    try:
        population_df[col] = pd.to_numeric(population_df[col], errors="ignore")
    except ValueError:
        continue


population_df.to_csv("../data/clean_data/population.csv", index=False)
population_df.head()
# Out:
# C:\Users\court\AppData\Local\Temp\ipykernel_45476\1728502546.py:22: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   population_df[col] = pd.to_numeric(population_df[col], errors="ignore")
#    fipstxt state       area_name  rural_urban_continuum_code_2013  \
# 0        0    US   United_States                              NaN
# 1     1000    AL         Alabama                              NaN
# 2     1001    AL  Autauga_County                              2.0
# 3     1003    AL  Baldwin_County                              3.0
# 4     1005    AL  Barbour_County                              6.0
#
#    rural_urban_continuum_code_2023  urban_influence_2013  \
# 0                              NaN                   NaN
# 1                              NaN                   NaN
# 2                              2.0                   2.0
# ...
